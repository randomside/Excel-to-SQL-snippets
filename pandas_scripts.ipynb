# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', 45)
pd.set_option('display.max_rows', 100)

# %%
df = pd.read_csv('dataset.csv', dtype={'PROVIDE_FLAG': str})

# %%
df.shape
# Out:
# (190156, 45)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190156 entries, 0 to 190155
# Data columns (total 45 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   sys_date                    190156 non-null  object
#  1   DOCUMENT                    190156 non-null  int64
#  2   YEAR                        190156 non-null  int64
#  3   ITEM_NO                     190156 non-null  int64
#  4   AUTO_POSTING                190156 non-null  int64
#  5   STORAGE_TYPE                189988 non-null  object
#  6   PROVIDE_FLAG                128 non-null     object
#  7   DOCUMENT_TYPE               190156 non-null  object
#  8   MOVEMENT_TYPE               190156 non-null  int64
#  9   MATERIAL                    190156 non-null  object
#  10  PLANT                       190156 non-null  object
#  11  STORAGE_LOCATION            190156 non-null  object
#  12  VALUATION                   1805 non-null    object
# ...

# %%
df
# Out:
#                    sys_date    DOCUMENT  YEAR  ITEM_NO  AUTO_POSTING  \
# 0       Feb  1 2021  1:00PM  1003346638  2021        1             0
# 1       Feb  1 2021  1:00PM  1003346638  2021        2             0
# 2       Feb  1 2021  1:00PM  1003346639  2021        1             0
# 3       Feb  1 2021  1:00PM  1003346639  2021        2             0
# 4       Feb  1 2021  1:00PM  1003346639  2021        3             0
# ...                     ...         ...   ...      ...           ...
# 190151  Feb 16 2021 12:00AM  2000519540  2021      110             0
# 190152  Feb 16 2021 12:00AM  2000519540  2021      120             0
# 190153  Feb 16 2021 12:00AM  2000519540  2021      130             0
# 190154  Feb 16 2021 12:00AM  2000519541  2021       10             0
# 190155  Feb 16 2021 12:00AM  2000519541  2021       20             0
#
#        STORAGE_TYPE PROVIDE_FLAG DOCUMENT_TYPE  MOVEMENT_TYPE     MATERIAL  \
# ...

# %%
df[['ITEM_NO', 'MATERIAL']].head(18)
# Out:
#     ITEM_NO     MATERIAL
# 0         1  BN61-16696A
# 1         2  0103-011580
# 2         1  BN96-46009E
# 3         2  0203-007064
# 4         3  BN02-00040B
# 5         4  BN02-00102B
# 6         5  BN39-02390A
# 7         6  BN61-13557P
# 8         7  BN61-15526A
# 9         8  BN61-15531A
# 10        9  BN61-15532A
# 11       10  BN61-15540A
# 12       11  BN61-15541A
# 13       12  BN63-17614A
# 14       13  BN63-17616A
# 15       14  BN96-45913A
# 16       15  IZ64-04033B
# 17       16  BN60-01534A

# %%
# df.count()

# %%
df.columns
# Out:
# Index(['sys_date', 'DOCUMENT', 'YEAR', 'ITEM_NO', 'AUTO_POSTING',
#        'STORAGE_TYPE', 'PROVIDE_FLAG', 'DOCUMENT_TYPE', 'MOVEMENT_TYPE',
#        'MATERIAL', 'PLANT', 'STORAGE_LOCATION', 'VALUATION', 'STOCK_TYPE',
#        'VENDOR', 'SUPPLY_PLANT', 'CUSTOMER', 'PURCHASE_ORDER',
#        'PURCHASE_ORDER_ITEM', 'SALES_ORDER', 'SALES_ORDER_ITEM',
#        'PRODUCTION_ORDER', 'RESERVATION', 'RESERVATION_ITEM', 'COST_CENTER',
#        'DEBIT_CREDIT', 'QUANTITY', 'UNIT', 'CURRENCY', 'AMOUNT_DOCUMENT',
#        'LOCAL_CURRENCY', 'AMOUNT_LOCAL', 'EXCHANGE_RATE', 'FROM_FACTOR',
#        'TO_FACTOR', 'RECEIVING_MATERIAL', 'RECEIVING_PLANT',
#        'RECEIVING_STORAGE_LOCATION', 'RECEIVING_VALUATION', 'DOCUMENT_REMARK',
#        'STORAGE_STOCK', 'STORAGE_AMOUNT', 'TOTAL_STOCK', 'TOTAL_AMOUNT',
#        'BARCODE_ID'],
#       dtype='object')

# %%
# df.iloc[0]
# df.iloc[[0, 1]]
# df.iloc[[0, 1], [0, 2]]

# %%
df['ITEM_NO'].value_counts().head(20)
# Out:
# 1     17586
# 2     17142
# 10    16072
# 3     14043
# 4     11937
# 5      9687
# 6      9598
# 7      9411
# 8      9222
# 9      8992
# 11     8649
# 12     8458
# 13     8064
# 14     7364
# 15     6166
# 16     4596
# 17     3401
# 18     2409
# 20     2158
# 19     1537
# Name: ITEM_NO, dtype: int64
